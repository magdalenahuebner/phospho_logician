# %%
import os
import pandas as pd
import numpy as np
from src.data.ksea_ztest import ksea_ztest

# %%
os.chdir('/Users/magdalena/OneDrive - Queen Mary, University of London/bezzlab/research/projects/phospho_logician/')
# os.chdir('/home/mhuebner/Desktop/bezzlab/research/projects/phospho_logician/')

# %%
# selecting cell line
cline = 'HL60'  # HL60, MCF7, NTERA2
mode = ''  # '', 'nas_', 'rd_nas_'
percentile = 99.5

# %%
# Load observational data and enz_sub relationships
# Has to be repeated for every cell line individually
obs = pd.read_csv('data/raw/ctamdb_dpoa_' + mode + cline + '.tsv', sep='\t')
enz_sub_omnipath = pd.read_csv('data/processed/facts/enz_sub_omnipath.csv')
enz_sub_cantley = pd.read_csv('data/processed/facts/enz_sub_cantley.csv')
kinases = pd.read_csv('data/processed/facts/kinase.csv')
phosphatases = pd.read_csv('data/processed/facts/phosphatase.csv')

# %%
# filter enz_sub_cantley data based on percentile column
enz_sub_cantley = enz_sub_cantley[enz_sub_cantley['percentile'] > percentile]
# merge enzu_sub relationships
enz_sub = pd.concat([enz_sub_omnipath, enz_sub_cantley], ignore_index=True)

# %%
enz_sub
# Out:
#        enzyme substrate    kpa kpa_class   tprot           pst residue_type  \
# 0      Q2M2I8    Q9BXS5   AAK1         K   AP1M1   AP1M1(T144)            T
# 1      Q2M2I8    Q96CW1   AAK1         K   AP2M1   AP2M1(T154)            T
# 2      Q2M2I8    Q96CW1   AAK1         K   AP2M1   AP2M1(T156)            T
# 3      Q2M2I8    P49757   AAK1         K    NUMB    NUMB(T102)            T
# 4      P00519    Q8IZP0   ABL1         K    ABI1    ABI1(Y213)            Y
# ...       ...       ...    ...       ...     ...           ...          ...
# 47985     NaN       NaN    ATM       NaN  TMEM51  TMEM51(S115)          NaN
# 47986     NaN       NaN  MYLK4       NaN     ATR     ATR(S435)          NaN
# 47987     NaN       NaN   GRK5       NaN  NAP1L4  NAP1L4(S125)          NaN
# 47988     NaN       NaN   GRK7       NaN    PCNP    PCNP(S119)          NaN
# 47989     NaN       NaN   PKCG       NaN   TACC2  TACC2(S2134)          NaN
#
#        residue_offset     modification  \
# 0               144.0  phosphorylation
# 1               154.0  phosphorylation
# 2               156.0  phosphorylation
# 3               102.0  phosphorylation
# 4               213.0  phosphorylation
# ...               ...              ...
# 47985             NaN              NaN
# 47986             NaN              NaN
# 47987             NaN              NaN
# 47988             NaN              NaN
# 47989             NaN              NaN
#
#                                                  sources  \
# 0      HPRD_MIMP;MIMP;PhosphoSite_MIMP;ProtMapper;SIG...
# 1        HPRD_MIMP;MIMP;PhosphoSite_MIMP;phosphoELM_MIMP
# 2      PhosphoSite;PhosphoSite_ProtMapper;ProtMapper;...
# 3      MIMP;PhosphoSite;PhosphoSite_MIMP;PhosphoSite_...
# 4      HPRD_MIMP;MIMP;PhosphoSite;PhosphoSite_MIMP;Ph...
# ...                                                  ...
# 47985                                                NaN
# 47986                                                NaN
# 47987                                                NaN
# 47988                                                NaN
# 47989                                                NaN
#
#                                               references  n_resources  \
# 0                                               11877461          4.0
# 1                                                    NaN          1.0
# 2                                      11877457;11877461          4.0
# 3                                      18657069;25904845          5.0
# 4      17389395;18083107;18328268;19534553;20598684;2...          5.0
# ...                                                  ...          ...
# 47985                                                NaN          NaN
# 47986                                                NaN          NaN
# 47987                                                NaN          NaN
# 47988                                                NaN          NaN
# 47989                                                NaN          NaN
#
#        n_references  percentile
# 0               1.0         NaN
# 1               0.0         NaN
# 2               2.0         NaN
# 3               2.0         NaN
# 4               7.0         NaN
# ...             ...         ...
# 47985           NaN       100.0
# 47986           NaN       100.0
# 47987           NaN       100.0
# 47988           NaN       100.0
# 47989           NaN       100.0
#
# [47990 rows x 14 columns]

# %%
# Data wrangling INPUT
# Reformat observations and enz_sub data
kt = enz_sub[['kpa', 'pst']].drop_duplicates()
obs = obs[['perturbagen', 'pst', 'fc']]
# Data is converted into df, where rows and cols correspond to phosphosite and perturbagens, respectively.
obs = obs.pivot(index='pst', columns='perturbagen', values='fc')
obs = obs.replace(np.nan, 'nan')

# %%
kt
# Out:
#          kpa           pst
# 0       AAK1   AP1M1(T144)
# 1       AAK1   AP2M1(T154)
# 2       AAK1   AP2M1(T156)
# 3       AAK1    NUMB(T102)
# 4       ABL1    ABI1(Y213)
# ...      ...           ...
# 47985    ATM  TMEM51(S115)
# 47986  MYLK4     ATR(S435)
# 47987   GRK5  NAP1L4(S125)
# 47988   GRK7    PCNP(S119)
# 47989   PKCG  TACC2(S2134)
#
# [47864 rows x 2 columns]

# %%
# kseaZtest function returns Z-scores and p-values for every phosphosite and perturbagen
ksea_df = ksea_ztest(kt, obs, graphics = False, min_sub = 1)

# %%
len(ksea_df.kpa.unique())
# Out:
# 475

# %%
# Assign activity status
ksea_df['status'] = 'unaffected'
ksea_df.loc[ksea_df['n_sub_data'] == 0, 'status'] = 'no_t'  # no observed targets
ksea_df.loc[(ksea_df['kpa'].isin(kinases['kinase'])) & (ksea_df['z_score'] > 0) & (
            ksea_df['p_val'] < 0.05), 'status'] = 'actv'
ksea_df.loc[(ksea_df['kpa'].isin(kinases['kinase'])) & (ksea_df['z_score'] < 0) & (
            ksea_df['p_val'] < 0.05), 'status'] = 'inhb'
ksea_df.loc[(ksea_df['kpa'].isin(phosphatases['phosphatase'])) & (ksea_df['z_score'] < 0) & (
            ksea_df['p_val'] < 0.05), 'status'] = 'actv'
ksea_df.loc[(ksea_df['kpa'].isin(phosphatases['phosphatase'])) & (ksea_df['z_score'] > 0) & (
            ksea_df['p_val'] < 0.05), 'status'] = 'inhb'

# %%
ksea_df
# Out:
#         kpa         pert     p_val  n_sub_data   mlog2fc   z_score  n_sub_db  \
# 0      AAK1        AC220  0.457885          16  0.026441  0.105764        19
# 1      AAK1      AT13148  0.266862          16 -0.155583 -0.622333        19
# 2      AAK1         AZ20  0.305968          16 -0.126828 -0.507311        19
# 3      AAK1      AZD1480  0.258157          16  0.162259  0.649038        19
# 4      AAK1      AZD3759  0.278232          16 -0.147026 -0.588102        19
# ...     ...          ...       ...         ...       ...       ...       ...
# 28970   ZAK        Torin  0.307838          41  0.078397  0.501987        42
# 28971   ZAK   Trametinib  0.424050          41 -0.029914 -0.191544        42
# 28972   ZAK       U73122  0.003693          41  0.418375  2.678905        42
# 28973   ZAK  Ulixertinib  0.043239          41  0.267725  1.714279        42
# 28974   ZAK  Vemurafenib  0.028686          41 -0.296804 -1.900471        42
#
#            status
# 0      unaffected
# 1      unaffected
# 2      unaffected
# 3      unaffected
# 4      unaffected
# ...           ...
# 28970  unaffected
# 28971  unaffected
# 28972  unaffected
# 28973  unaffected
# 28974  unaffected
#
# [28975 rows x 8 columns]

# %%
ksea_df.value_counts('status')
# Out:
# status
# unaffected    24585
# inhb           3209
# actv           1120
# dtype: int64

# %%
# export df to csv
ksea_df.to_csv('data/processed/facts/ksea_' + mode + cline + '_mp_cantley.csv', index=False)

# %%
# Write Prolog file
with open('models/facts/ksea_' + mode + cline + '_mp_cantley.pl', 'w') as file:
    for index, row in ksea_df.iterrows():
        var1 = "ksea('{}', '{}', {}, {}).".format(row['pert'], row['kpa'], row['status'], row['p_val'])
        file.write(var1 + '\n')
